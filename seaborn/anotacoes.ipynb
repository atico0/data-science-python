# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\Users\luisg\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde=False )
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=False, bins=3 )
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.distplot(tips['total_bill'],kde=False, bins=60 )
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.jointplot(x='total_bill',y='tip', data=tips)

# %%
sns.jointplot(x='total_bill',y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip', data=tips, kind='hex')

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.pairplot(tips,hue='day')

# %%
sns.pairplot(tips,hue='sex', palette='coolwarm')

# %%
sns.pairplot(tips,hue='day', palette='coolwarm')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips, palette='rainbow')
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=tips, palette='rainbow', orient='h')
# Out:
# <AxesSubplot:>

# %%
sns.violinplot(x='day', y='tip', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day', y='tip', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.violinplot(x='day', y='tip', data=tips, hue='sex', split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, jitter=False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day', y='total_bill', data=tips, hue='sex', dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, hue='sex', dodge=True)
# Out:
# C:\Users\luisg\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day', y='total_bill', data=tips, color='black')
sns.violinplot(x='day', y='total_bill', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')#factorplot agora é catplot

# %%
flights = sns.load_dataset('flights')
tips = sns.load_dataset('tips')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
crr = tips.corr()
crr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(crr)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(crr, cmap='cool')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(crr, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(crr, cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %%
pf = flights.pivot_table(values='passengers', index='month', columns='year')
pf
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(pf)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma', linecolor='white')
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma', linecolor='white', linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma', linecolor='red', linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma', linecolor='white', linewidth=4)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma', linecolor='white', linewidth=1, annot=True)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(pf, cmap='magma', annot=True)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(pf)

# %%
sns.clustermap(pf, standard_scale=1)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex',palette='coolwarm')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'])

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['',''])

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], scatter_kws={'s':90})

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='sex', row='time')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day', aspect=1, height=1)
#size agora é height

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day', aspect=5, height=5)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day', aspect=0.6, height=8)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day', aspect=0.6, height=11)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day', aspect=0.1, height=8)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o','v'], col='day', aspect=8, height=8)

# %%
iris =sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
g = sns.PairGrid(iris)
g

# %%
g.map(plt.scatter)

# %%
g.map_diag(plt.hist)#oque acontece se não ficar reatribuindo o pairgrid para g após já ter colocado grafico

# %%
g = sns.PairGrid(iris)
g.map_diag(plt.hist)

# %%
g = sns.PairGrid(iris)
g.map_upper(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_lower(sns.kdeplot)

# %%
g = sns.PairGrid(iris)  
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='species')

# %%
g = sns.FacetGrid(tips, col='time', row='smoker')

# %%
g.map(plt.hist, 'total_bill')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('dark')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('white')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.countplot(x='sex', data=tips)
sns.despine()

# %%
sns.countplot(x='sex', data=tips)
sns.despine(left=True,bottom=True)

# %%
sns.countplot(x='sex', data=tips)
sns.despine(left=True,bottom=True, right=False,top=False)

# %%
plt.figure(figsize=[12,12])
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=[12,8])
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=[8,12])
sns.countplot(x='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, height=3)#size agora é height

# %%
sns.set_context('paper')
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.set_context('notebook')
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.set_context('poster')
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.set_context('poster', font_scale=6)
sns.lmplot(x='total_bill', y='tip', data=tips)
# Out:
# C:\Users\luisg\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\luisg\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout(*args, **kwargs)

# %%
sns.set_context('poster', font_scale=0.4)
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.set_context('poster')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='hsv')
