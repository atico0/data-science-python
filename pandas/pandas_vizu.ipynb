# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df2 = pd.read_csv('df2', index_col=0)

# %%
df2.head()
# Out:
#                  b         c         d
# a
# 0.039762  0.218517  0.103423  0.957904
# 0.937288  0.041567  0.899125  0.977680
# 0.780504  0.008948  0.557808  0.797510
# 0.672717  0.247870  0.264071  0.444358
# 0.053829  0.520124  0.552264  0.190008

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10 entries, 0.0397619861339051 to 0.9081621790575398
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   b       10 non-null     float64
#  1   c       10 non-null     float64
#  2   d       10 non-null     float64
# dtypes: float64(3)
# memory usage: 320.0 bytes

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area()
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df2.plot.bar()
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:xlabel='a'>

# %%
df1['A'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
df1.plot.line(x='A', y='D')
# Out:
# <AxesSubplot:xlabel='A'>

# %%
df1.plot.scatter(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='D')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c='D', cmap='inferno')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D'])
# Out:
# C:\Users\luisg\anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['D']*20)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(1000,2), columns=['A','B'])
df
# Out:
#             A         B
# 0    0.351421  0.266925
# 1    0.878583  0.625415
# 2    0.713337  0.605197
# 3    0.965149  0.508102
# 4    0.772232  0.203899
# ..        ...       ...
# 995  0.333399  0.811594
# 996  0.731680  0.446612
# 997  0.935962  0.771103
# 998  0.200809  0.294062
# 999  0.046310  0.608292
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df.plot.hexbin(x='A', y='B', gridsize=30)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df.plot.hexbin(x='A', y='B', gridsize=60, cmap='Accent')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>
